# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

data = {
    'year': [2011, 2012, 2013, 2014, 2015],
    'mileage': [50000, 40000, 30000, 20000, 10000],
    'make': ['Toyota', 'Toyota', 'Toyota', 'Toyota', 'Toyota'],
    'model': ['Corolla', 'Corolla', 'Corolla', 'Corolla', 'Corolla'],
    'price': [8000, 9000, 10000, 11000, 12000]
}

df=pd.DataFrame(data)

# %%
df.head()
# Out:
#    year  mileage    make    model  price
# 0  2011    50000  Toyota  Corolla   8000
# 1  2012    40000  Toyota  Corolla   9000
# 2  2013    30000  Toyota  Corolla  10000
# 3  2014    20000  Toyota  Corolla  11000
# 4  2015    10000  Toyota  Corolla  12000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     5 non-null      int64
#  1   mileage  5 non-null      int64
#  2   make     5 non-null      object
#  3   model    5 non-null      object
#  4   price    5 non-null      int64
# dtypes: int64(3), object(2)
# memory usage: 328.0+ bytes

# %%
df.describe()
# Out:
#               year       mileage        price
# count     5.000000      5.000000      5.00000
# mean   2013.000000  30000.000000  10000.00000
# std       1.581139  15811.388301   1581.13883
# min    2011.000000  10000.000000   8000.00000
# 25%    2012.000000  20000.000000   9000.00000
# 50%    2013.000000  30000.000000  10000.00000
# 75%    2014.000000  40000.000000  11000.00000
# max    2015.000000  50000.000000  12000.00000

# %%
x=df[['year','mileage']]
y=df['price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
print(y_pred)
# Out:
# [9000.]

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
print(f"Mean squared error:{mse}")
# Out:
# Mean squared error:0.0

# %%
new_data = {
    'year': [2016],
    'mileage': [15000]
}
new_df = pd.DataFrame(new_data)

new_pred = model.predict(new_df)
print(f"Predicted Price for the new input: {new_pred[0]}")
# Out:
# Predicted Price for the new input: 11500.000014999998

# %%
import joblib
joblib.dump(model, 'car_price_model.pkl')
# Out:
# ['car_price_model.pkl']
